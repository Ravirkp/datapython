# %% [markdown]
# # Planks constant

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
wavelength = np.array([635, 570, 540, 500, 460], dtype=np.float16)
wavelength = wavelength / 1000000000
frequency = 300000000 / wavelength 
retarding_potential = np.array([.34, .53, .66, .84, 1.06])
x = frequency
y = retarding_potential
plt.plot(x,y,'go--')
plt.title('Pancks Constants')
plt.xlabel('Frequency')
plt.ylabel('Potential')
plt.show()

# %% [markdown]
# # Retarding Potential

# %%
photcurrent = np.array([0, 0.006, .036, .184, .427, 1.023, 1.392, 1.675, 1.774], dtype=np.float16)
applied_potential = np.array([-.34, -.24, -.14, 0, .20, .70, 1.20, 1.70, 2], dtype=np.float16)
x = applied_potential
y = photcurrent
plt.plot(x,y,'ro--')
plt.title('Red 635nm')
plt.xlabel('Frequency')
plt.ylabel('Potential')
plt.show()

# %%
photcurrent = np.array([0,.015, .085, .281, .698, 1.85, 2.9, 3.82, 4.74], dtype=np.float16)
applied_potential = np.array([-.83, -.63, -.43, -.23, 0, .5, 1, 1.5, 2], dtype=np.float16)
x = applied_potential
y = photcurrent
plt.plot(x,y,'go--')
plt.title('Green 500nm')
plt.xlabel('Frequency')
plt.ylabel('Potential')
plt.show()

# %%
photcurrent = np.array([0, .047, .241, .468, 1.475, 2.45, 3.26, 4.08], dtype=np.float16)
applied_potential = np.array([-.53, -.33, -.13, 0, .5, 1, 1.5, 2], dtype=np.float16)
x = applied_potential
y = photcurrent
plt.plot(x,y,'yo--')
plt.title('Yellow1 570nm')
plt.xlabel('Frequency')
plt.ylabel('Potential')
plt.show()

# %%
photcurrent = np.array([0, .096, .533, .768, 1.987, 3.14, 4.08, 5.16], dtype=np.float16)
applied_potential = np.array([-.70, -.40, -.10, 0, .5, 1, 1.5, 2], dtype=np.float16)
x = applied_potential
y = photcurrent
plt.plot(x,y,'yo--')
plt.title('Yellow 540nm')
plt.xlabel('Frequency')
plt.ylabel('Potential')
plt.show()

# %%
photcurrent = np.array([0, .023, .140, .513, 1.156, 1.801, 2.500, 3.52, 4.40, 4.86], dtype=np.float16)
applied_potential = np.array([-1.07, -.77, -.47, -.17, .13, .43, .73, 1.24, 1.74, 2.00], dtype=np.float16)
x = applied_potential
y = photcurrent
plt.plot(x,y,'o--')
plt.title('Blue 460nm')
plt.xlabel('Frequency')
plt.ylabel('Potential')
plt.show()
